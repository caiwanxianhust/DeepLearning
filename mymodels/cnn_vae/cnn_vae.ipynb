# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
from cnn_vae import CnnVae, Evaluate

# %%
n = 5
vocab_size = 5000

# %%
cnnvae = CnnVae(n=n, vocab_size=vocab_size)

# %%
cnnvae.vae.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# inp_seq (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 10, 64)       320000      inp_seq[0][0]
# __________________________________________________________________________________________________
# en_gcnn_0 (GCNN)                (None, 10, 64)       24704       embedding[0][0]
# __________________________________________________________________________________________________
# en_gcnn_1 (GCNN)                (None, 10, 64)       24704       en_gcnn_0[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 64)           0           en_gcnn_1[0][0]
# ...

# %%
keras.utils.plot_model(cnnvae.vae, "../model_img/vae.png", show_layer_names=True, show_shapes=True)

# %%
keras.utils.plot_model(cnnvae.genmodel, "../model_img/vae_gen.png", show_layer_names=True, show_shapes=True)
